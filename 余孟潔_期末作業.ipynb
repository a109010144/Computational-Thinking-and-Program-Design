# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010144/Computational-Thinking-and-Program-Design/blob/main/%E4%BD%99%E5%AD%9F%E6%BD%94_%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 組員名單:
# A109010003蔡予倫
# A109010015李承諭
# A109010144余孟潔
# A109010147廖宇騰
#
#
# 腳本:
# "輸入你的名字:"
#  宇騰
# 您好',宇騰,'我是您的私人助理料與藤
#
# "輸入現在時間(24小時制,若下午一點請回答13):"
# 5<time<12 早安
# Time=12 午安
# 12<Time<18 晚安
# 18<time<24 晚安，你這時間到底在幹嘛?
# 看手機
# “原來你在看手機”
#
# “那請問你想吃東西嗎”
# [0] 要
# [1] 不要
# [2] 不知道
# ["臭豆腐","珍珠奶茶","牛肉麵"]真的很好吃
#
# 要
# A=”請問你想吃甚麼?”
# B=“請問你還想吃甚麼?”
# C=“請問你還想要吃甚麼?”
# 不要
# "我覺得你應該吃點東西"
# A="請問您想吃甚麼?"
# B="請問您還想吃甚麼?"
# C="請問您還想要吃甚麼?"
# 不知道
# "那還是吃一些東西吧"
# A="請問您想吃甚麼?"
# B="請問您還想吃甚麼?"
# C="請問您還想要吃甚麼?"
# 其他
# "叫你回答要或不要，你到底在回甚麼東西，我不管，你給我吃"
# A="請問您想吃甚麼?"
# B="請問您還想吃甚麼?"
# C="請問您還想要吃甚麼?"
#
# “想吃那麼多東西喔，很胖欸，該怎麼決定呢?”
# “不然我們來猜拳好了!”
# “你贏你就吃” A
# “我贏你就吃” B
# “平手就吃” C
#
# “請出拳”
# [0]剪刀
# [1]石頭
# [2]布
#
# 你出的拳””
#
# 電腦出拳””
#
# “你贏了，那就吃”A
# “我贏了，那吃”B
# “平手，那吃”C
#
# “你想吃幾份”
# D
# “每份多少錢”
# F
# "你以為我會幫你算好齁。自己算好嗎!!我好貼心～讓你吃東西還能順便訓練算數能力"
# D*F
# “你居然答對了，不可思議”
# 其他
# “再算算看”
# “不用那麼多啦，會不會算數”
# “你也過太爽，國小數學都不會，多一點”
#
# “需要直接幫你叫外送嗎?”
# [0]好
# "其實我沒有這個功能哈哈哈,我這是為了教你學會獨立不要依賴別人!"
# [1]不用了我自己買
# "真的喔，你人好好"
# 其他
# “你真的很欠扁”
#
# “還有甚麼問題嗎”
# [0]沒有
# 感謝你的光臨
# [1]有
# 系統已自動關機
# 其他
# 系統已自動關機

# %%
n=input("輸入你的名字:")
print('您好',n,'我是您的私人助理料與藤')
time=int(input("輸入現在時間(24小時制,若下午一點請回答13):"))
if 5<time<12:
  print('早安')
elif time==12:
  print('午安')
elif 12<time<18:
  print('午安')
elif time== 18:
  print('晚安')
elif 18<time<24:
  print('晚安')
else:
  d=input("這時間你到底在幹嘛?")
  print('原來你在',d)

E=int(input("那請問您想吃東西嗎[0]要[1]不要[2]不知道"))
food=["臭豆腐","珍珠奶茶","牛肉麵"]
for i in food:
    print(i,"真的很好吃")
if E==0:
  A=input("請問您想吃甚麼?")
  B=input("請問您還想吃甚麼?")
  C=input("請問您還想要吃甚麼?")
elif E==1:
  print("我覺得你應該吃點東西")
  A=input("請問您想吃甚麼?")
  B=input("請問您還想吃甚麼?")
  C=input("請問您還想要吃甚麼?")
elif E==2:
  print("那還是吃一些東西吧")
  A=input("請問您想吃甚麼?")
  B=input("請問您還想吃甚麼?")
  C=input("請問您還想要吃甚麼?")
else:
  print("叫你回答要或不要，你到底在回甚麼東西，我不管，你給我吃")
  A=input("請問您想吃甚麼?")
  B=input("請問您還想吃甚麼?")
  C=input("請問您還想要吃甚麼?")
print("想吃那麼多東西喔，很胖ㄟ，該怎麼決定呢?")
print("不然我們來猜拳好了!")
print('你贏我就吃',A)
print('我贏你就吃',B)
print('平手就吃',C)
my_choice=int(input("請出拳[0]剪刀[1]石頭[2]布"))
print('你出的拳:',my_choice)
import random
com_choice=random.randint(0,2)
print("電腦出拳為",com_choice)
if my_choice==((com_choice+1))%3:
  print("你贏了,那就吃",A)
elif com_choice==(my_choice+1)%3:
   print("我贏了,那吃",B)
else:
  print("平手,那吃",C)
D=int(input("您想吃幾份:"))
F=int(input("每份多少錢:"))
print("你以為我會幫你算好齁。自己算好嗎!!我好貼心～讓你吃東西還能順便訓練算數能力")
target=D*F
while True:
    guess=int(input("輸入您算的價格:"))
    if guess==target:
        print("你居然達對了，不可思議")
        break
    else:
        print("再算算看")
        if guess>target:
            print("不用這麼多啦，會不會算數")
        else:
            print("你也過太爽連國小數學都不會，多一點")
print("需要直接幫你叫外送嗎")
G=int(input("[0]好[1]不用了我自己買"))
if G==0:
  print("其實我沒有這個功能哈哈哈,我這是為了教你學會獨立不要依賴別人!")
elif G==1:
  print("真的喔，你人好好")
else:
  print("你真的很欠扁")
print("還有甚麼問題嗎")
H=int(input("[0]沒有[1]有"))
if H==0:
  print("感謝您的光臨")
elif H==1:
    print("系統已自動關機")

else:
    print("系統已自動關機")
